# %% [markdown]
# # Market Microstructure Study
#
# This notebook is the narrative companion to the repository scripts. It is intentionally lightweight so the project can be shared publicly and extended later.
#
# ## Question
#
# How do volatility and liquidity interact with a simple spread proxy?

# %%
import pandas as pd
from pathlib import Path

root = Path.cwd().resolve().parents[0]
df = pd.read_csv(root / 'data' / 'synthetic_microstructure_data.csv', parse_dates=['date'])
df.head()

# %% [markdown]
# ## Suggested Extensions
#
# - add rolling correlations
# - compare market-cap buckets
# - extend the regression with interaction terms
# - test an event-window version of the analysis
